# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.rag_pipeline import RAGPipeline

# %%
rag = RAGPipeline()
    
result = rag.query("What are the most common complaints about Credit Cards?")
print("Question:", result["question"])
print("\nAnswer:\n", result["answer"])
# Out:
# INFO:src.rag_pipeline:✅ Loaded 1,375,327 chunks from parquet
# INFO:sentence_transformers.base.model:No device provided, using cpu
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json "HTTP/1.1 200 OK"
# INFO:sentence_transformers.base.model:Loading SentenceTransformer model from sentence-transformers/all-MiniLM-L6-v2.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config_sentence_transformers.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/modules.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/sentence_bert_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/1110a243fdf4706b3f48f1d95db1a4f5529b4d41/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/config.json "HTTP/1.1 200 OK"
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/configuration_phi3.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/configuration_phi3.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/configuration_phi3.py "HTTP/1.1 200 OK"
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# [transformers] This model config has set a `rope_parameters['original_max_position_embeddings']` field, to be used together with `max_position_embeddings` to determine a scaling factor. Please set the `factor` field of `rope_parameters`with this ratio instead -- we recommend the use of this field over `original_max_position_embeddings`, as it is compatible with most model architectures.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/configuration_phi3.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/configuration_phi3.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/modeling_phi3.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/modeling_phi3.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/modeling_phi3.py "HTTP/1.1 200 OK"
# modeling_phi3.py:   0%|          | 0.00/73.8k [00:00<?, ?B/s]
# [transformers] A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi_hyphen_3_dot_5_hyphen_mini_hyphen_instruct.2fe192450127e6a83f7441aef6e3ca586c338b77.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi_hyphen_3_dot_5_hyphen_mini_hyphen_instruct.2fe192450127e6a83f7441aef6e3ca586c338b77.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/model.safetensors "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/model.safetensors.index.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/model.safetensors.index.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/model.safetensors.index.json "HTTP/1.1 200 OK"
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/microsoft/Phi-3.5-mini-instruct/revision/main "HTTP/1.1 200 OK"
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/2fe192450127e6a83f7441aef6e3ca586c338b77/model-00001-of-00002.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/2fe192450127e6a83f7441aef6e3ca586c338b77/model-00002-of-00002.safetensors "HTTP/1.1 302 Found"
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/generation_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/generation_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/generation_config.json "HTTP/1.1 200 OK"
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/custom_generate/generate.py "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/configuration_phi3.py "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/configuration_phi3.py "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/tokenizer_config.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/tokenizer_config.json "HTTP/1.1 200 OK"
# tokenizer_config.json:   0%|          | 0.00/3.98k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/microsoft/Phi-3.5-mini-instruct/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/microsoft/Phi-3.5-mini-instruct/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/tokenizer.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/tokenizer.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/tokenizer.json "HTTP/1.1 200 OK"
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/tokenizer.model "HTTP/1.1 302 Found"
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/added_tokens.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/added_tokens.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/added_tokens.json "HTTP/1.1 200 OK"
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/special_tokens_map.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/special_tokens_map.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/microsoft/Phi-3.5-mini-instruct/2fe192450127e6a83f7441aef6e3ca586c338b77/special_tokens_map.json "HTTP/1.1 200 OK"
# special_tokens_map.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/chat_template.jinja "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/microsoft/Phi-3.5-mini-instruct/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# [transformers] The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Passing `generation_config` together with generation-related arguments=({'temperature', 'max_new_tokens', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=600) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 rag = RAGPipeline()
#       2
# ----> 3 result = rag.query("What are the most common complaints about Credit Cards?")
#       4 print("Question:", result["question"])
#       5 print("\nAnswer:\n", result["answer"])
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\src\rag_pipeline.py:65, in RAGPipeline.query(self, question, k)
#      52         # Stronger, stricter prompt
#      53         prompt = f"""You are a precise financial complaints analyst for CrediTrust.
#      54 Use **only** the excerpts below to answer the question.
#      55 Do not add external knowledge. Do not make up information.
#    (...)     62
#      63 Answer:"""
# ---> 65         output = self.generator(prompt, return_full_text=False)
#      66         answer = output[0]['generated_text'].strip()
#      68         return {
#      69             "question": question,
#      70             "answer": answer,
#      71             "retrieved_metadata": metadata[:3],
#      72             "num_chunks_used": k
#      73         }
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\pipelines\text_generation.py:299, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     249 def __call__(self, text_inputs, **kwargs):
#     250     """
#     251     Complete the prompt(s) given as inputs.
#     252
#    (...)    297           ids of the generated text.
#     298     """
# --> 299     return super().__call__(text_inputs, **kwargs)
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\pipelines\base.py:1276, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1268     return next(
#    1269         iter(
#    1270             self.get_iterator(
#    (...)   1273         )
#    1274     )
#    1275 else:
# -> 1276     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\pipelines\base.py:1283, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1281 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1282     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1283     model_outputs = self.forward(model_inputs, **forward_params)
#    1284     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1285     return outputs
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\pipelines\base.py:1175, in Pipeline.forward(self, model_inputs, **forward_params)
#    1173     with inference_context():
#    1174         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1175         model_outputs = self._forward(model_inputs, **forward_params)
#    1176         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1177 return model_outputs
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\pipelines\text_generation.py:403, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     400 if "generation_config" not in generate_kwargs:
#     401     generate_kwargs["generation_config"] = self.generation_config
# --> 403 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     405 if isinstance(output, ModelOutput):
#     406     generated_sequence = output.sequences
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\generation\utils.py:2584, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2581 model_kwargs["use_cache"] = generation_config.use_cache
#    2583 # 9. Call generation mode
# -> 2584 result = decoding_method(
#    2585     self,
#    2586     input_ids,
#    2587     logits_processor=prepared_logits_processor,
#    2588     stopping_criteria=prepared_stopping_criteria,
#    2589     generation_config=generation_config,
#    2590     **generation_mode_kwargs,
#    2591     **model_kwargs,
#    2592 )
#    2594 return result
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\generation\utils.py:2784, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2777 model_forward = (
#    2778     self.get_compiled_call(generation_config.compile_config)
#    2779     if self._valid_auto_compile_criteria(model_kwargs, generation_config)
#    2780     else self.__call__
#    2781 )
#    2783 prefill_consumed = False
# -> 2784 outputs = self._prefill(
#    2785     input_ids,
#    2786     generation_config,
#    2787     model_kwargs,
#    2788     is_first_iteration=not generation_config.is_assistant,
#    2789 )
#    2791 while self._has_unfinished_sequences(this_peer_finished, synced_gpus, device=input_ids.device):
#    2792     if prefill_consumed:
#
# File c:\Users\Hello\Desktop\kaim\rag-complaint-chatbot\venv\Lib\site-packages\transformers\generation\utils.py:3824, in GenerationMixin._prefill(self, input_ids, generation_config, model_kwargs, is_first_iteration)
#    3822 # Usual prefill
#    3823 if generation_config.prefill_chunk_size is None:
# -> 3824     model_inputs = self.prepare_inputs_for_generation(
#    3825         input_ids,
#    3826         next_sequence_length=next_sequence_length,
#    3827         is_first_iteration=is_first_iteration,
#    3828         **model_kwargs,
#    3829     )
#    3830     return self(**model_inputs, return_dict=True)
#    3832 # Chunked prefill (for very large contexts)
#    3833 else:
#    3834     # Even if we are not compiling the forward, flex is always compiled when used. With chunked prefill, we may
#    3835     # end up needing just a bit more graphs than the default (which is 8). Doing this avoids very cryptic warnings
#
# File ~\.cache\huggingface\modules\transformers_modules\microsoft\Phi_hyphen_3_dot_5_hyphen_mini_hyphen_instruct\2fe192450127e6a83f7441aef6e3ca586c338b77\modeling_phi3.py:1298, in Phi3ForCausalLM.prepare_inputs_for_generation(self, input_ids, past_key_values, attention_mask, inputs_embeds, **kwargs)
#    1296 if isinstance(past_key_values, Cache):
#    1297     cache_length = past_key_values.get_seq_length()
# -> 1298     past_length = past_key_values.seen_tokens
#    1299     max_cache_length = past_key_values.get_max_length()
#    1300 else:
#
# AttributeError: 'DynamicCache' object has no attribute 'seen_tokens'
